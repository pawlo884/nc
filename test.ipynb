# %% [markdown]
# full_change_2025_09_03_08_16_04_xml

# %%
print(len(full_change_2025_09_03_08_16_04_xml))
# Out:
#   Cell In[1], line 1
#     print(len(full_change2025-09-03T08-16-04.xml))
#                               ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
